# %%
import json
import pandas as pd
import re
from rapidfuzz.fuzz import token_set_ratio

# ----------- Normalization Functions -----------

def normalize_text(text):
    # Lowercase and strip punctuation (keep apostrophes for contractions)
    return re.sub(r"[^\w\s']", '', text.lower()).strip()

# ----------- Fuzzy Matching Function -----------

def refined_fuzzy_match(words_list, utterance_text, threshold=85):
    utterance_clean = normalize_text(utterance_text)
    utterance_words = utterance_clean.split()
    n = len(utterance_words)
    norm_words = [normalize_text(w["word"]) for w in words_list]

    best_score = 0
    best_i = None
    best_window = []

    # Step 1: Find best fuzzy-matching window
    for window_size in range(n, n + 6):  # small window buffer
        for i in range(len(norm_words) - window_size + 1):
            window = norm_words[i:i+window_size]
            window_text = ' '.join(window)
            score = token_set_ratio(window_text, utterance_clean)
            if score > best_score and score >= threshold:
                best_score = score
                best_i = i
                best_window = window

    # Step 2: Slide for exact submatch within best window
    if best_i is not None:
        for i in range(best_i, best_i + len(best_window) - n + 1):  # typo was `besi`
            if norm_words[i:i+n] == utterance_words:
                return words_list[i]["start"], words_list[i+n-1]["end"], 100  # perfect alignment

        # fallback: use full fuzzy window timing
        return words_list[best_i]["start"], words_list[best_i + len(best_window) - 1]["end"], best_score  # typo: `wt_ords_list`

    return None, None, 0

# ----------- Load Dataset A (Transcript JSON) -----------

with open("/home/cleode5a7/Desktop/analyses_friends_annotations/friends_annotations/annotation_results/Speech2Text/s1/friends_s01e01a_aa.json", "r") as f:
    transcript_json = json.load(f)

words_list = transcript_json["results"]["channels"][0]["alternatives"][0]["words"]

# ----------- Load Dataset B (Utterance CSV) -----------

df_utterances = pd.read_csv("../meld_data/utterrance_ep1.csv")

# ----------- Apply Fuzzy Matching to Each Utterance -----------

results = []
for utterance in df_utterances["Utterance"]:
    start, end, score = refined_fuzzy_match(words_list, utterance)
    results.append((start, end, score))

df_utterances[["start", "end", "match_score"]] = pd.DataFrame(results, index=df_utterances.index)

# ----------- Save or Display -----------

# %%
df_utterances
# Out:
#     Sr No.                                          Utterance   Speaker  \
# 0     5550  Alright, so I'm back in high school, I'm stand...  Chandler
# 1     5551                          Oh, yeah. Had that dream.       All
# 2     5552  Then I look down, and I realize there's a phon...  Chandler
# 3     5553                                     Instead of...?      Joey
# 4     5554                                      That's right.  Chandler
# 5     5555                              Never had that dream.      Joey
# 6     5556                                                No.    Phoebe
# 7     5557         All of a sudden, the phone starts to ring.  Chandler
# 8     7646  I don't want to be single, okay? I just... I j...      Ross
# 9     7647                 And I just want a million dollars!  Chandler
# 10    7648                                           Rachel?!    Monica
# 11     209                                   Really? A purse?      Joey
# 12    9633                                Well, it was loong.      Ross
# 13     201                                               Hey.      Joey
# 14     202                                               Hey!    Phoebe
# 15    1481                                         Oh my God!    Monica
# 16    1482                 I know, I know, I'm such an idiot.      Paul
# 17    1485  My brother's going through that right now, he'...    Monica
# 18    1486  Well, you might try accidentally breaking some...      Paul
# 19    1487                                              -leg?    Monica
# 20    1488       That's one way! Me, I- I went for the watch.      Paul
# 21    1489                      You actually broke her watch?    Monica
# 22    1492                                Barry, I'm sorry...    Rachel
# 23    1493                                   I am so sorry...    Rachel
# 24    1494  I know you probably think that this is all abo...    Rachel
# 25    4790                                Hey, this-  Heyy...      Ross
# 26    1064                                   Okay. It’s Emma.    Monica
# 27    4595                            Oh, look, wish me luck!    Rachel
# 28    4596                                          What for?    Monica
# 29    4597         I'm gonna go get one of those  job things.    Rachel
# 30     795                                                Hi.      Ross
# 31    1600  You know you probably didn't know this, but ba...      Ross
# 32    1601                                            I knew.    Rachel
# 33    1602  You did! Oh.... I always figured you just thou...      Ross
# 34    1603                                             I did.    Rachel
# 35    1604                                                Oh.      Ross
# 36    8791                                        Oh really?!    Rachel
# 37    8792         Yeah. Did you tell someone that I was gay?       Tag
# 38    1605  Listen, do you think- and try not to let my in...      Ross
# 39    8793          Oh, did you not want people to know that?    Rachel
# 40    1606                                          Sometime?      Ross
# 41    1607                                             Maybe?      Ross
# 42    1608                                     Yeah, maybe...    Rachel
# 43    1609                      Okay... okay, maybe I will...      Ross
#
#      Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  Episode  \
# 0    neutral   neutral          559             0       1        1
# 1    neutral   neutral          559             1       1        1
# 2   surprise  negative          559             2       1        1
# 3   surprise  negative          559             3       1        1
# 4    neutral   neutral          559             4       1        1
# 5    neutral   neutral          559             5       1        1
# 6    neutral   neutral          559             6       1        1
# 7    neutral   neutral          559             7       1        1
# 8    sadness  negative          769             0       1        1
# 9       fear  negative          769             1       1        1
# 10  surprise  negative          769             2       1        1
# 11  surprise  positive           19             0       1        1
# 12   sadness  negative          958             0       1        1
# 13   neutral   neutral           19             0       1        1
# 14   neutral   neutral           19             1       1        1
# 15  surprise  negative          152             0       1        1
# 16       joy  positive          152             1       1        1
# 17   neutral   neutral          152             4       1        1
# 18   neutral   neutral          152             5       1        1
# 19   neutral   neutral          152             6       1        1
# 20   neutral   neutral          152             7       1        1
# 21  surprise  positive          152             8       1        1
# 22   sadness  negative          152             9       1        1
# 23   sadness  negative          152            10       1        1
# 24   sadness  negative          152            11       1        1
# 25       joy  positive          485             0       1        1
# 26   neutral   neutral          100             0       1        1
# 27       joy  positive          467             0       1        1
# 28   neutral   neutral          467             1       1        1
# 29   neutral   neutral          467             2       1        1
# 30   neutral   neutral           75             0       1        1
# 31      fear  negative          164             0       1        1
# 32   neutral   neutral          164             1       1        1
# 33  surprise  positive          164             2       1        1
# 34   neutral   neutral          164             3       1        1
# 35   sadness  negative          164             4       1        1
# 36  surprise  positive          880             0       1        1
# 37   neutral   neutral          880             1       1        1
# 38      fear  negative          164             5       1        1
# 39       joy  positive          880             2       1        1
# 40   neutral   neutral          164             6       1        1
# 41   neutral   neutral          164             7       1        1
# 42       joy  positive          164             8       1        1
# 43       joy  positive          164             9       1        1
#
#                  StartTime                 EndTime    start      end  \
# 0   0 days 00:01:19.037000  0 days 00:01:25.417000   53.870   60.510
# 1   0 days 00:01:25.627000  0 days 00:01:27.169000      NaN      NaN
# 2   0 days 00:01:27.378000  0 days 00:01:31.465000   62.690   65.840
# 3   0 days 00:01:34.928000  0 days 00:01:35.600000   71.350   72.082
# 4   0 days 00:01:35.600000  0 days 00:01:36.892000   72.136   72.980
# 5   0 days 00:01:37.055000  0 days 00:01:37.973000      NaN      NaN
# 6   0 days 00:01:37.973000  0 days 00:01:38.629000  133.430  133.902
# 7   0 days 00:01:38.723000  0 days 00:01:42.851000   75.030   78.930
# 8   0 days 00:03:22.660000  0 days 00:03:25.829000  209.252  219.554
# 9   0 days 00:03:29.959000  0 days 00:03:33.086000  218.470  220.900
# 10  0 days 00:03:34.214000  0 days 00:03:35.297000  226.150  227.166
# 11  0 days 00:04:43.666000  0 days 00:04:45.033000      NaN      NaN
# 12  0 days 00:05:25.450000  0 days 00:05:30.120000      NaN      NaN
# 13  0 days 00:10:11.861000  0 days 00:10:14.990000  240.330  240.742
# 14  0 days 00:10:14.990000  0 days 00:10:15.133000  240.330  240.742
# 15  0 days 00:10:22.204000  0 days 00:10:24.289000  754.864  756.154
# 16  0 days 00:10:24.498000  0 days 00:10:28.793000  756.688  760.030
# 17  0 days 00:10:36.427000  0 days 00:10:40.680000  766.922  771.774
# 18  0 days 00:10:40.890000  0 days 00:10:44.392000  771.812  776.930
# 19  0 days 00:10:44.560000  0 days 00:10:46.144000  777.000  777.620
# 20  0 days 00:10:48.773000  0 days 00:10:50.315000      NaN      NaN
# 21  0 days 00:10:50.775000  0 days 00:10:52.651000  781.788  783.734
# 22  0 days 00:10:53.277000  0 days 00:10:54.737000  793.930  795.670
# 23  0 days 00:10:54.737000  0 days 00:10:56.422000  795.820  797.446
# 24  0 days 00:10:56.614000  0 days 00:11:06.706000  797.788  820.674
# 25         0 days 00:13:13  0 days 00:13:38.775000      NaN      NaN
# 26  0 days 00:13:23.916000  0 days 00:13:26.460000      NaN      NaN
# 27  0 days 00:16:45.504000  0 days 00:16:46.088000      NaN      NaN
# 28  0 days 00:16:46.088000  0 days 00:16:47.192000      NaN      NaN
# 29  0 days 00:16:47.339000  0 days 00:16:50.633000      NaN      NaN
# 30  0 days 00:19:28.917000  0 days 00:19:30.251000  103.630  104.380
# 31  0 days 00:20:43.492000  0 days 00:20:49.080000      NaN      NaN
# 32  0 days 00:20:50.540000  0 days 00:20:51.707000  315.412  315.726
# 33  0 days 00:20:52.084000  0 days 00:20:58.138000      NaN      NaN
# 34  0 days 00:20:58.882000  0 days 00:20:59.684000  172.710  173.266
# 35  0 days 00:20:59.684000  0 days 00:21:00.931000  181.224  181.486
# 36  0 days 00:21:02.844000  0 days 00:21:03.970000  181.224  182.070
# 37  0 days 00:21:04.338000  0 days 00:21:06.597000      NaN      NaN
# 38  0 days 00:21:05.514000  0 days 00:21:16.983000      NaN      NaN
# 39  0 days 00:21:06.807000  0 days 00:21:10.142000      NaN      NaN
# 40  0 days 00:21:13.105000  0 days 00:21:15.817000  168.230  168.738
# 41  0 days 00:21:15.817000  0 days 00:21:17.031000  423.032  423.234
# 42  0 days 00:21:18.235000  0 days 00:21:21.821000      NaN      NaN
# 43  0 days 00:21:20.529000  0 days 00:21:31.872000      NaN      NaN
#
#     match_score
# 0     98.989899
# 1      0.000000
# 2     96.551724
# 3    100.000000
# 4    100.000000
# 5      0.000000
# 6    100.000000
# 7    100.000000
# 8     96.296296
# 9    100.000000
# 10   100.000000
# 11     0.000000
# 12     0.000000
# 13   100.000000
# 14   100.000000
# 15   100.000000
# 16   100.000000
# 17   100.000000
# 18    97.902098
# 19   100.000000
# 20     0.000000
# 21   100.000000
# 22   100.000000
# 23    88.888889
# 24    97.805643
# 25     0.000000
# 26     0.000000
# 27     0.000000
# 28     0.000000
# 29     0.000000
# 30   100.000000
# 31     0.000000
# 32   100.000000
# 33     0.000000
# 34   100.000000
# 35   100.000000
# 36   100.000000
# 37     0.000000
# 38     0.000000
# 39     0.000000
# 40    94.117647
# 41   100.000000
# 42     0.000000
# 43     0.000000
